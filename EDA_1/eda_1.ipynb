# %%
import pandas as pd
import dtale
import statistics as st
import category_encoders as ce
from sklearn import preprocessing
import seaborn as sns

# %%
df = pd.read_csv('data/wine_cleared.zip')
df.head(3)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
#
#     designation  points      price           province           region_1  \
# 0  Vulkà Bianco      87  35.363389  Sicily & Sardinia               Etna
# 1      Avidagos      87  15.000000              Douro            unknown
# 2       unknown      87  14.000000             Oregon  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm

# %%
df['price_round'] = df['price'].round().astype(int)

# %%
regex = '\d{4}' # регулярное выражение для нахождения чисел
df['year'] = df['title'].str.findall(regex).str.get(0)

# %%
df['is_usa'] = df['country'].apply(lambda x: 1 if x == 'US' else 0)

# %%
df['is_france'] = df['country'].apply(lambda x: 1 if x == 'France' else 0)
df['is_italy'] = df['country'].apply(lambda x: 1 if x == 'Italy' else 0)

# %%
df['year'] = pd.to_datetime(df['year'], errors='coerce')

# для сравнения используем год, заполняем значения признака old_wine, где год вина меньше 2010
df['old_wine'] = df['year'].apply(lambda x: 1 if x.year < 2010 else 0) 
df['old_wine'].sum()
# Out:
# 39765

# %%
regex = '\((.*?)\)'
df['locality'] = df['title'].str.findall(regex).str.get(0)

# %%
import matplotlib.pyplot as plt # библиотека визуализации
from scipy import stats # библиотека для расчетов

plt.subplot(1, 2, 1) # задаем сетку рисунка количество строк и столбцов
stats.probplot(df['points'], plot=plt) # qq plot

plt.subplot(1, 2, 2) # располагаем второй рисунок рядом
plt.hist(df['points']) # гистограмма распределения признака

plt.tight_layout() # чтобы графики не наезжали другу на друга, используем tight_layout

plt.show() # просмотр графика

# %%
country_population = pd.read_csv('data/country_population.zip', sep=';')
country_population.head(2)
# Out:
#   country     population
# 0   China  1,411,778,724
# 1   India  1,386,584,581

# %%
df = df.join(country_population.set_index('country'), on='country')
df.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points      price           province region_1    taster_name  \
# 0  Vulkà Bianco      87  35.363389  Sicily & Sardinia     Etna  Kerin O’Keefe
# 1      Avidagos      87  15.000000              Douro  unknown     Roger Voss
#
#   taster_twitter_handle  ...         variety               winery price_round  \
# 0          @kerinokeefe  ...     White Blend              Nicosia          35
# 1            @vossroger  ...  Portuguese Red  Quinta dos Avidagos          15
#
#         year is_usa  is_france  is_italy  old_wine  locality  population
# 0 2013-01-01      0          0         1         0      Etna  59,097,904
# 1 2011-01-01      0          0         0         0     Douro  10,347,892
#
# [2 rows x 21 columns]

# %%
country_area = pd.read_csv('data/country_area.zip', sep=';')
country_area.head(2)
# Out:
#   country        area
# 0  Russia  17075400.0
# 1  Canada   9984670.0

# %%
df = df.join(country_area.set_index('country'), on='country')
df.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points      price           province region_1    taster_name  \
# 0  Vulkà Bianco      87  35.363389  Sicily & Sardinia     Etna  Kerin O’Keefe
# 1      Avidagos      87  15.000000              Douro  unknown     Roger Voss
#
#   taster_twitter_handle  ...               winery price_round       year  \
# 0          @kerinokeefe  ...              Nicosia          35 2013-01-01
# 1            @vossroger  ...  Quinta dos Avidagos          15 2011-01-01
#
#    is_usa is_france  is_italy  old_wine  locality  population      area
# 0       0         0         1         0      Etna  59,097,904  301230.0
# 1       0         0         0         0     Douro  10,347,892   92391.0
#
# [2 rows x 22 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points      price           province region_1    taster_name  \
# 0      87  35.363389  Sicily & Sardinia     Etna  Kerin O’Keefe
# 1      87  15.000000              Douro  unknown     Roger Voss
#
#   taster_twitter_handle                                          title  ...  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)  ...
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)  ...
#
#                 winery price_round       year is_usa  is_france  is_italy  \
# 0              Nicosia          35 2013-01-01      0          0         1
# 1  Quinta dos Avidagos          15 2011-01-01      0          0         0
#
#    old_wine  locality  population      area
# 0         0      Etna  59,097,904  301230.0
# 1         0     Douro  10,347,892   92391.0
#
# [2 rows x 21 columns]

# %%
df['years_diff'] = (pd.to_datetime('2022/01/12') - df['year']).dt.days
max(df.years_diff)
# Out:
# 98627.0

# %%
ord_encoder = ce.OrdinalEncoder(cols=['year'])
year_col = ord_encoder.fit_transform(df['year'])
data = pd.concat([df, year_col], axis=1)
data.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points      price           province region_1    taster_name  \
# 0      87  35.363389  Sicily & Sardinia     Etna  Kerin O’Keefe
# 1      87  15.000000              Douro  unknown     Roger Voss
#
#   taster_twitter_handle                                          title  ...  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)  ...
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)  ...
#
#         year is_usa  is_france is_italy  old_wine  locality  population  \
# 0 2013-01-01      0          0        1         0      Etna  59,097,904
# 1 2011-01-01      0          0        0         0     Douro  10,347,892
#
#        area years_diff year
# 0  301230.0     3298.0    1
# 1   92391.0     4029.0    2
#
# [2 rows x 23 columns]

# %%
encoder = ce.OneHotEncoder(cols=['taster_name']) # указываем столбец для кодирования
type_bin = encoder.fit_transform(df['taster_name'])
df = pd.concat([df, type_bin], axis=1)

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot: >

# %%
df = df.drop(['is_usa', 'is_france', 'is_italy', 'price_round', 'area'], axis=1)

# %%
# Проверяем, что сильно скоррелированных признаков не осталось
sns.heatmap(df.corr(), annot=True, linewidths=.5)
# Out:
# <AxesSubplot: >

# %%
n_col = len(df.columns)
bin_encoder = ce.BinaryEncoder(cols=['taster_twitter_handle']) # указываем столбец для кодирования
type_bin = bin_encoder.fit_transform(df['taster_twitter_handle'])
df = pd.concat([df, type_bin], axis=1)
res = len(df.columns) - n_col
res
# Out:
# 5

# %%
r_scaler = preprocessing.RobustScaler()

# кодируем исходный датасет
df['price'] = r_scaler.fit_transform(df[['price']])

fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('Распределения после RobustScaler')

sns.kdeplot(df['price'], ax=ax1)
# Out:
# <AxesSubplot: title={'center': 'Распределения после RobustScaler'}, xlabel='price', ylabel='Density'>

# %%
s_scaler = preprocessing.StandardScaler()
# кодируем исходный датасет
df['price'] = s_scaler.fit_transform(df[['price']])
df['price'][129968]
# Out:
# -0.13551516993245466

# %%
calls_list = [
    [460, '2013-12-17 04:55:39', '2013-12-17 04:55:44', '2013-12-17 04:55:45'],
    [12, '2013-12-16 20:03:20', '2013-12-16 20:03:22', '2013-12-16 20:07:13'],
    [56, '2013-12-16 20:03:20', '2013-12-16 20:03:20', '2013-12-16 20:05:04'],
    [980, '2013-12-16 20:03:20','2013-12-16 20:03:27', '2013-12-16 20:03:29'],
    [396, '2013-12-16 20:08:27', '2013-12-16 20:08:28','2013-12-16 20:12:03'],
    [449, '2013-12-16 20:03:20', '2013-12-16 20:03:25','2013-12-16 20:05:00'],
    [397, '2013-12-16 20:08:25', '2013-12-16 20:08:27', '2013-12-16 20:09:59'],
    [398, '2013-12-16 20:01:23', '2013-12-16 20:01:23', '2013-12-16 20:04:58'],
    [452, '2013-12-16 20:03:20', '2013-12-16 20:03:21','2013-12-16 20:04:55'],
    [440, '2013-12-16 20:03:20', '2013-12-16 20:04:26', '2013-12-16 20:04:32']
]

calls = pd.DataFrame(calls_list, columns = ['client_id',  'agent_date', 'created_at' ,'end_date'])

calls['agent_date'] = pd.to_datetime(calls['agent_date'])
calls['created_at'] = pd.to_datetime(calls['created_at'])
calls['end_date'] = pd.to_datetime(calls['end_date'])

# %%
calls['duration'] = (calls['end_date'] - calls['created_at']).dt.seconds
calls
# Out:
#    client_id          agent_date          created_at            end_date  \
# 0        460 2013-12-17 04:55:39 2013-12-17 04:55:44 2013-12-17 04:55:45
# 1         12 2013-12-16 20:03:20 2013-12-16 20:03:22 2013-12-16 20:07:13
# 2         56 2013-12-16 20:03:20 2013-12-16 20:03:20 2013-12-16 20:05:04
# 3        980 2013-12-16 20:03:20 2013-12-16 20:03:27 2013-12-16 20:03:29
# 4        396 2013-12-16 20:08:27 2013-12-16 20:08:28 2013-12-16 20:12:03
# 5        449 2013-12-16 20:03:20 2013-12-16 20:03:25 2013-12-16 20:05:00
# 6        397 2013-12-16 20:08:25 2013-12-16 20:08:27 2013-12-16 20:09:59
# 7        398 2013-12-16 20:01:23 2013-12-16 20:01:23 2013-12-16 20:04:58
# 8        452 2013-12-16 20:03:20 2013-12-16 20:03:21 2013-12-16 20:04:55
# 9        440 2013-12-16 20:03:20 2013-12-16 20:04:26 2013-12-16 20:04:32
#
#    duration
# 0         1
# 1       231
# 2       104
# 3         2
# 4       215
# 5        95
# 6        92
# 7       215
# 8        94
# 9         6

# %%
calls['time_connection'] = (calls['created_at'] - calls['agent_date']).dt.seconds
calls['time_connection'].sum()
# Out:
# 89

# %%
calls['is_connection'] = calls['duration'].apply(lambda x: 1 if x > 10 else 0)
calls['is_connection'].sum()
# Out:
# 7

# %%
calls['time_diff'] = (calls['end_date'] - calls['agent_date']).dt.seconds
calls['time_diff'].sum()
# Out:
# 1144

# %%
calls = calls.drop(columns=['agent_date', 'created_at' ,'end_date'], axis=1)
calls.head(2)
# Out:
#    client_id  duration  time_connection  is_connection  time_diff
# 0        460         1                5              0          6
# 1         12       231                2              1        233

# %%
# инициализируем информацию об одежде
clothing_list = [
    ['xxs', 'dress'],
    ['xxs', 'skirt'],
    ['xs', 'dress'],
    ['s', 'skirt'],
    ['m', 'dress'],
    ['l', 'shirt'],
    ['s', 'coat'],
    ['m', 'coat'],
    ['xxl', 'shirt'],
    ['l', 'dress']
]

clothing = pd.DataFrame(clothing_list, columns = ['size',  'type'])
clothing
# Out:
#   size   type
# 0  xxs  dress
# 1  xxs  skirt
# 2   xs  dress
# 3    s  skirt
# 4    m  dress
# 5    l  shirt
# 6    s   coat
# 7    m   coat
# 8  xxl  shirt
# 9    l  dress

# %%
ord_encoder = ce.OrdinalEncoder()
data_bin = ord_encoder.fit_transform(clothing[['size', 'type']])
clothing = pd.concat([clothing, data_bin], axis=1)

clothing
# Out:
#    size   type  size  type
# 0   xxs  dress     1     1
# 1   xxs  skirt     1     2
# 2    xs  dress     2     1
# 3     s  skirt     3     2
# 4     m  dress     4     1
# 5     l  shirt     5     3
# 6     s   coat     3     4
# 7     m   coat     4     4
# 8   xxl  shirt     6     3
# 9     l  dress     5     1

# %%
encoder = ce.OneHotEncoder(cols=['type']) # указываем столбец для кодирования
type_bin = encoder.fit_transform(clothing['type'])
clothing = pd.concat([clothing, type_bin], axis=1)

clothing
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\По работе\SkillFactory\Data_Science_Course\EDA_1\eda_1.ipynb Ячейка 32 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/EDA_1/eda_1.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> encoder = ce.OneHotEncoder(cols=['type']) # указываем столбец для кодирования
# ----> <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/EDA_1/eda_1.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> type_bin = encoder.fit_transform(clothing['type'])
#       <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/EDA_1/eda_1.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> clothing = pd.concat([clothing, type_bin], axis=1)
#       <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/EDA_1/eda_1.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a> clothing
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:859, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     855 # non-optimized default implementation; override when a better
#     856 # method is possible for a given clustering algorithm
#     857 if y is None:
#     858     # fit method of arity 1 (unsupervised transformation)
# --> 859     return self.fit(X, **fit_params).transform(X)
#     860 else:
#     861     # fit method of arity 2 (supervised transformation)
#     862     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\utils.py:306, in BaseEncoder.fit(self, X, y, **kwargs)
#     303     if X[self.cols].isnull().any().any():
#     304         raise ValueError('Columns to be encoded can not contain null')
# --> 306 self._fit(X, y, **kwargs)
#     308 # for finding invariant columns transform without y (as is done on the test set)
#     309 X_transformed = self.transform(X, override_return_df=True)
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\one_hot.py:118, in OneHotEncoder._fit(self, X, y, **kwargs)
#     106 oe_missing_strat = {
#     107     'error': 'error',
#     108     'return_nan': 'return_nan',
#     109     'value': 'value',
#     110     'indicator': 'return_nan',
#     111 }[self.handle_missing]
#     112 self.ordinal_encoder = OrdinalEncoder(
#     113     verbose=self.verbose,
#     114     cols=self.cols,
#     115     handle_unknown='value',
#     116     handle_missing=oe_missing_strat,
#     117 )
# --> 118 self.ordinal_encoder = self.ordinal_encoder.fit(X)
#     119 self.mapping = self.generate_mapping()
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\utils.py:306, in BaseEncoder.fit(self, X, y, **kwargs)
#     303     if X[self.cols].isnull().any().any():
#     304         raise ValueError('Columns to be encoded can not contain null')
# --> 306 self._fit(X, y, **kwargs)
#     308 # for finding invariant columns transform without y (as is done on the test set)
#     309 X_transformed = self.transform(X, override_return_df=True)
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\ordinal.py:103, in OrdinalEncoder._fit(self, X, y, **kwargs)
#     101 if not self.mapping_supplied:
#     102     self.mapping = None
# --> 103 _, categories = self.ordinal_encoding(
#     104     X,
#     105     mapping=self.mapping,
#     106     cols=self.cols,
#     107     handle_unknown=self.handle_unknown,
#     108     handle_missing=self.handle_missing
#     109 )
#     110 self.mapping = categories
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\ordinal.py:223, in OrdinalEncoder.ordinal_encoding(X_in, mapping, cols, handle_unknown, handle_missing)
#     221 for col in cols:
#     222     nan_identity = np.nan
# --> 223     categories = list(X[col].unique())
#     224     if util.is_category(X[col].dtype):
#     225         # Avoid using pandas category dtype meta-data if possible, see #235, #238.
#     226         if X[col].dtype.ordered:
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
bin_encoder = ce.BinaryEncoder(cols=['type']) # указываем столбец для кодирования
type_bin = bin_encoder.fit_transform(clothing['type'])
clothing = pd.concat([clothing, type_bin], axis=1)

clothing
# Out:
#   size   type  type_1  type_2  type_3  type_4  type_0  type_1  type_2
# 0  xxs  dress       1       0       0       0       0       0       1
# 1  xxs  skirt       0       1       0       0       0       1       0
# 2   xs  dress       1       0       0       0       0       0       1
# 3    s  skirt       0       1       0       0       0       1       0
# 4    m  dress       1       0       0       0       0       0       1
# 5    l  shirt       0       0       1       0       0       1       1
# 6    s   coat       0       0       0       1       1       0       0
# 7    m   coat       0       0       0       1       1       0       0
# 8  xxl  shirt       0       0       1       0       0       1       1
# 9    l  dress       1       0       0       0       0       0       1

# %%
list_of_dicts = [
 {'product': 'Product1', 'price': 1200, 'payment_type': 'Mastercard'},
 {'product': 'Product2', 'price': 3600, 'payment_type': 'Visa'},
 {'product': 'Product3', 'price': 7500, 'payment_type': 'Amex'}
]
df = pd.DataFrame(list_of_dicts)
df
# Out:
#     product  price payment_type
# 0  Product1   1200   Mastercard
# 1  Product2   3600         Visa
# 2  Product3   7500         Amex

# %%
encoder = ce.OneHotEncoder(cols=['product','payment_type'])
cols = encoder.fit_transform(df[['product','payment_type']])
df = pd.concat([df, cols], axis=1)
df
# Out:
#     product  price payment_type  product_1  product_2  product_3  \
# 0  Product1   1200   Mastercard          1          0          0
# 1  Product2   3600         Visa          0          1          0
# 2  Product3   7500         Amex          0          0          1
#
#    payment_type_1  payment_type_2  payment_type_3
# 0               1               0               0
# 1               0               1               0
# 2               0               0               1
