# %%
import pandas as pd

from prophet import Prophet

url = 'https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv'

df = pd.read_csv(url)

df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
model = Prophet()
model.fit(df)
# Out:
# 18:55:28 - cmdstanpy - INFO - Chain [1] start processing
# 18:55:29 - cmdstanpy - INFO - Chain [1] done processing

# %%
future_df = model.make_future_dataframe(periods=365)

future_df.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast_df = model.predict(future_df)
forecast_df[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.206605    7.465764    8.893545
# 3266 2017-01-16  8.531590    7.805309    9.281699
# 3267 2017-01-17  8.318985    7.594979    9.041897
# 3268 2017-01-18  8.151637    7.391483    8.865361
# 3269 2017-01-19  8.163528    7.423925    8.874837

# %%
fig = model.plot(forecast_df)

# %%
fig = model.plot_components(forecast_df)
