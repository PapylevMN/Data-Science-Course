# %%
# Загрузка библиотек
import numpy as np # для работы с массивами
import pandas as pd # для работы с DataFrame 
from sklearn import datasets # для импорта данных
import seaborn as sns # для визуализации статистических данных
import matplotlib.pyplot as plt # для построения графиков

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'PRICE']
boston_data = pd.read_csv('data/housing.csv', header=None, delimiter=r"\s+", names=column_names)
boston_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
# составляем матрицу наблюдений без дополнительного столбца из единиц
A = boston_data[['CHAS', 'LSTAT', 'CRIM','RM']]
y = boston_data[['PRICE']]
# стандартизируем векторы в столбцах матрицы A
A_cent = A - A.mean()
A_st = A_cent/np.linalg.norm(A_cent, axis=0)
A_st.describe().round(2)
# Out:
#          CHAS   LSTAT    CRIM      RM
# count  506.00  506.00  506.00  506.00
# mean    -0.00   -0.00   -0.00   -0.00
# std      0.04    0.04    0.04    0.04
# min     -0.01   -0.07   -0.02   -0.17
# 25%     -0.01   -0.04   -0.02   -0.03
# 50%     -0.01   -0.01   -0.02   -0.00
# 75%     -0.01    0.03    0.00    0.02
# max      0.16    0.16    0.44    0.16

# %%
print(np.linalg.norm(A_st, axis=0))
# Out:
# [1. 1. 1. 1.]

# %%
# стандартизируем вектор целевой переменной
y_cent = y - y.mean()
y_st = y_cent/np.linalg.norm(y_cent)

# %%
# вычислим OLS-оценку для стандартизированных коэффициентов
w_hat_st=np.linalg.inv(A_st.T@A_st)@A_st.T@y_st
print(w_hat_st.values)
# Out:
# [[ 0.11039956]
#  [-0.45220423]
#  [-0.09108766]
#  [ 0.38774848]]

# %%
# матрица Грама
A_st.T @ A_st
# Out:
#            CHAS     LSTAT      CRIM        RM
# CHAS   1.000000 -0.053929 -0.055892  0.091251
# LSTAT -0.053929  1.000000  0.455621 -0.613808
# CRIM  -0.055892  0.455621  1.000000 -0.219247
# RM     0.091251 -0.613808 -0.219247  1.000000

# %%
x_1 = np.array([5.1, 1.8, 2.1, 10.3, 12.1, 12.6]).T
x_2 = np.array([10.2, 3.7, 4.1, 20.5, 24.2, 24.1]).T
x_3 = np.array([2.5, 0.9, 1.1, 5.1, 6.1, 6.3]).T
A = np.column_stack((x_1, x_2, x_3))
print(A)
print(np.linalg.matrix_rank(A))
print(np.linalg.det(A))
np.corrcoef(A)
# Out:
# [[ 5.1 10.2  2.5]
#  [ 1.8  3.7  0.9]
#  [ 2.1  4.1  1.1]
#  [10.3 20.5  5.1]
#  [12.1 24.2  6.1]
#  [12.6 24.1  6.3]]
# 3
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# d:\По работе\SkillFactory\Data_Science_Course\MATH_ML_2\vector_standart.ipynb Cell 8 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/MATH_ML_2/vector_standart.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> print(A)
#       <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/MATH_ML_2/vector_standart.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> print(np.linalg.matrix_rank(A))
# ----> <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/MATH_ML_2/vector_standart.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> print(decimal(np.linalg.det(A)))
#       <a href='vscode-notebook-cell:/d%3A/%D0%9F%D0%BE%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B5/SkillFactory/Data_Science_Course/MATH_ML_2/vector_standart.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> np.corrcoef(A)
#
# File <__array_function__ internals>:180, in det(*args, **kwargs)
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\linalg\linalg.py:2151, in det(a)
#    2149 a = asarray(a)
#    2150 _assert_stacked_2d(a)
# -> 2151 _assert_stacked_square(a)
#    2152 t, result_t = _commonType(a)
#    2153 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File c:\Users\Администратор.000\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\linalg\linalg.py:204, in _assert_stacked_square(*arrays)
#     202 m, n = a.shape[-2:]
#     203 if m != n:
# --> 204     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square
